# %%
from mm_driver import write_matrix_a, write_matrix_b, start_calculation, read_offset_a_matrix, read_offset_b_matrix, read_offset_prod_matrix
from matrix_mult import matrix_mult, generate_random_matrices, generate_basic_matrices, generate_basic_matrices_value, print_matrix
import time
import numpy as np

a, b = generate_basic_matrices_value(16, 16, 4)

write_matrix_a(a)
write_matrix_b(b)
x = read_offset_a_matrix()
y = read_offset_b_matrix()

print_matrix(x)
print()
print_matrix(y)

print()
print("Starting Calculation")
start_time = time.time()

start_calculation()

end_time = time.time()

# Calculate the duration
duration = (end_time - start_time) * 1000
print("duration(ms): ",duration)

prod = read_offset_prod_matrix()

print()
print("RESULT:")
print_matrix(prod)
# Out:
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
# 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#
# Starting Calculation
# duration(ms):  1.1141300201416016
#
# RESULT:
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256
# 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256 256

# %%
# Initialize a list to store the duration of each calculation
# this will be used for the report later 
calculation_times = []


for i in range(10): 

    a, b = generate_random_matrices(16, 16)

    write_matrix_a(a)
    write_matrix_b(b)
    
    expected_value = matrix_mult(a,b)
    print(f"Starting Calculation {i+1}")
    start_time = time.time()

    start_calculation()

    end_time = time.time()

    duration = (end_time - start_time) * 1000
    calculation_times.append(duration)
    
    print("duration(ms): ",duration)
    prod = read_offset_prod_matrix()
    
#     print_matrix(prod)
#     print()
#     print_matrix(expected_value)
    
    if np.allclose(expected_value,prod): 
        print(f"Calculation {i+1} Passed!")
    else: 
       print(f"Calculation {i+1} Failed!") 
    

# Calculate the average calculation time
average_time = sum(calculation_times) / len(calculation_times)

# Print the report
print("\nCalculation Times Report")
for i, duration in enumerate(calculation_times):
    print(f"Calculation {i+1}: {duration} ms")
print(f"Average Calculation Time: {average_time} ms")
# Out:
# Starting Calculation 1
# duration(ms):  0.33974647521972656
# Calculation 1 Passed!
# Starting Calculation 2
# duration(ms):  0.308990478515625
# Calculation 2 Passed!
# Starting Calculation 3
# duration(ms):  0.3008842468261719
# Calculation 3 Passed!
# Starting Calculation 4
# duration(ms):  0.3368854522705078
# Calculation 4 Passed!
# Starting Calculation 5
# duration(ms):  0.31185150146484375
# Calculation 5 Passed!
# Starting Calculation 6
# duration(ms):  0.2925395965576172
# Calculation 6 Passed!
# Starting Calculation 7
# duration(ms):  0.38695335388183594
# Calculation 7 Passed!
# Starting Calculation 8
# duration(ms):  0.3151893615722656
# Calculation 8 Passed!
# Starting Calculation 9
# duration(ms):  0.2913475036621094
# Calculation 9 Passed!
# Starting Calculation 10
# duration(ms):  0.3383159637451172
# Calculation 10 Passed!
#
# Calculation Times Report
# Calculation 1: 0.33974647521972656 ms
# Calculation 2: 0.308990478515625 ms
# Calculation 3: 0.3008842468261719 ms
# Calculation 4: 0.3368854522705078 ms
# Calculation 5: 0.31185150146484375 ms
# Calculation 6: 0.2925395965576172 ms
# Calculation 7: 0.38695335388183594 ms
# Calculation 8: 0.3151893615722656 ms
# Calculation 9: 0.2913475036621094 ms
# Calculation 10: 0.3383159637451172 ms
# Average Calculation Time: 0.32227039337158203 ms

# %%
# Initialize a list to store the duration of each calculation
# this will be used for the report later 
calculation_times = []

for i in range(10): 

    a, b = generate_random_matrices(16, 16)
    
    print(f"Starting Calculation {i+1}")
    start_time = time.time()

    matrix_mult(a,b)

    end_time = time.time()

    # Calculate the duration for this calculation
    duration = (end_time - start_time) * 1000
    calculation_times.append(duration)
    
    print("duration(ms): ",duration)
    

# Calculate the average calculation time
average_time = sum(calculation_times) / len(calculation_times)

# Print the report
print("\nCalculation Times Report")
for i, duration in enumerate(calculation_times):
    print(f"Calculation {i+1}: {duration} ms")
print(f"Average Calculation Time: {average_time} ms")
# Out:
# Starting Calculation 1
# duration(ms):  55.71126937866211
# Starting Calculation 2
# duration(ms):  54.489850997924805
# Starting Calculation 3
# duration(ms):  54.5501708984375
# Starting Calculation 4
# duration(ms):  58.306217193603516
# Starting Calculation 5
# duration(ms):  54.63910102844238
# Starting Calculation 6
# duration(ms):  53.88927459716797
# Starting Calculation 7
# duration(ms):  54.33297157287598
# Starting Calculation 8
# duration(ms):  57.268381118774414
# Starting Calculation 9
# duration(ms):  54.485321044921875
# Starting Calculation 10
# duration(ms):  54.28814888000488
#
# Calculation Times Report
# Calculation 1: 55.71126937866211 ms
# Calculation 2: 54.489850997924805 ms
# Calculation 3: 54.5501708984375 ms
# Calculation 4: 58.306217193603516 ms
# Calculation 5: 54.63910102844238 ms
# Calculation 6: 53.88927459716797 ms
# Calculation 7: 54.33297157287598 ms
# Calculation 8: 57.268381118774414 ms
# Calculation 9: 54.485321044921875 ms
# Calculation 10: 54.28814888000488 ms
# Average Calculation Time: 55.19607067108154 ms
